# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore')

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('survey_results_public_2022.csv')
df = data.copy()
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format
df.describe()
# Out:
#        ResponseId  \
# count   73,268.00
# mean    36,634.50
# std     21,150.79
# min          1.00
# 25%     18,317.75
# 50%     36,634.50
# 75%     54,951.25
# max     73,268.00
#
#                                                                            CompTotal  \
# count                                                                      38,422.00
# mean       23,424,340,221,747,959,297,504,942,608,856,691,548,764,873,498,296,320.00
# std     4,591,478,187,816,173,887,222,705,851,032,486,873,136,741,673,856,925,696.00
# min                                                                             0.00
# 25%                                                                        30,000.00
# 50%                                                                        77,500.00
# 75%                                                                       154,000.00
# max   900,000,000,000,000,060,934,480,090,350,342,481,100,335,261,807,995,256,832.00
#
# ...

# %%
df.describe(include='all')
# Out:
#           ResponseId                      MainBranch           Employment  \
# count   73268.000000                           73268                71709
# unique           NaN                               6                  103
# top              NaN  I am a developer by profession  Employed, full-time
# freq             NaN                           53507                42962
# mean    36634.500000                             NaN                  NaN
# std     21150.794099                             NaN                  NaN
# min         1.000000                             NaN                  NaN
# 25%     18317.750000                             NaN                  NaN
# 50%     36634.500000                             NaN                  NaN
# 75%     54951.250000                             NaN                  NaN
# max     73268.000000                             NaN                  NaN
#
#           RemoteWork CodingActivities  \
# count          58958            58899
# ...

# %%
df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                  7142
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                    5301
# ...

# %%
df.head()
# Out:
#    ResponseId  \
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#
#                                                                       MainBranch  \
# 0                                                                  None of these
# 1                                                 I am a developer by profession
# 2  I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                 I am a developer by profession
# 4                                                 I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
# ...

# %%
pd.options.display.max_colwidth = 100
df.loc[df.DevType.str.contains('data scientist|data or business analyst', case=False ,na=False)].DevType
# Out:
# 2        Data scientist or machine learning specialist;Developer, front-end;Engineer, data;Engineer, site...
# 39       Developer, back-end;Database administrator;DevOps specialist;Cloud infrastructure engineer;Data ...
# 40       Developer, front-end;Engineer, data;Developer, full-stack;Developer, back-end;Developer, desktop...
# 41                          Data scientist or machine learning specialist;Engineer, data;Developer, back-end
# 50                       Data scientist or machine learning specialist;Student;Academic researcher;Scientist
#                                                         ...
# 73229    Data scientist or machine learning specialist;Developer, back-end;Project manager;Data or busine...
# 73234    Data scientist or machine learning specialist;Developer, front-end;Developer, full-stack;Develop...
# 73254                 Data scientist or machine learning specialist;Data or business analyst;Product manager
# ...

# %%
dff = df.loc[df.DevType.str.contains('data scientist|data or business analyst', case=False ,na=False)]
dff.head(1)
# Out:
#    ResponseId  \
# 2           3
#
#                                                                       MainBranch  \
# 2  I am not primarily a developer, but I write code sometimes as part of my work
#
#             Employment                            RemoteWork CodingActivities  \
# 2  Employed, full-time  Hybrid (some remote, some in-person)            Hobby
#
#                                            EdLevel  \
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                                                              LearnCode  \
# 2  Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, foru...
#
#                                                                     LearnCodeOnline  \
# 2  Technical documentation;Blogs;Programming Games;Written Tutorials;Stack Overflow
#
#   LearnCodeCoursesCert YearsCode YearsCodePro  \
# 2                  NaN        14            5
#
# ...

# %%
dff.describe()
# Out:
#        ResponseId                         CompTotal  VCHostingPersonal use  \
# count    5,742.00                          3,504.00                   0.00
# mean    37,209.77      2,853,881,278,828,625,408.00                    NaN
# std     21,186.74    168,934,344,599,866,114,048.00                    NaN
# min          3.00                              0.00                    NaN
# 25%     18,657.25                         35,000.00                    NaN
# 50%     37,755.50                         85,000.00                    NaN
# 75%     55,936.50                        155,250.00                    NaN
# max     73,268.00 10,000,000,000,000,000,000,000.00                    NaN
#
#        VCHostingProfessional use  WorkExp  ConvertedCompYearly
# count                       0.00 3,386.00             3,462.00
# mean                         NaN    11.96           175,376.63
# std                          NaN    10.11           672,266.51
# ...

# %%
dff['CompFreq_number'] = dff.CompFreq.apply(lambda x : (52/12) if x=='Weekly' else 12 )
dff.loc[dff.CompFreq == 'Monthly', 'CompFreq_number'] = 1

dff[['CompTotal', 'CompFreq', 'CompFreq_number']]
# Out:
#        CompTotal CompFreq  CompFreq_number
# 2      32,000.00   Yearly            12.00
# 39           NaN  Monthly             1.00
# 40    130,000.00   Yearly            12.00
# 41     19,000.00  Monthly             1.00
# 50           NaN      NaN            12.00
# ...          ...      ...              ...
# 73229 325,000.00   Yearly            12.00
# 73234        NaN   Weekly             4.33
# 73254 115,000.00   Yearly            12.00
# 73264 107,000.00   Yearly            12.00
# 73267        NaN      NaN            12.00
#
# [5742 rows x 3 columns]

# %%
dff['Salary'] = dff.CompTotal / dff.CompFreq_number
dff[['CompTotal', 'CompFreq', 'CompFreq_number', 'Salary',  'WorkExp']]
# Out:
#        CompTotal CompFreq  CompFreq_number    Salary  WorkExp
# 2      32,000.00   Yearly            12.00  2,666.67      NaN
# 39           NaN  Monthly             1.00       NaN      NaN
# 40    130,000.00   Yearly            12.00 10,833.33      NaN
# 41     19,000.00  Monthly             1.00 19,000.00     3.00
# 50           NaN      NaN            12.00       NaN     4.00
# ...          ...      ...              ...       ...      ...
# 73229 325,000.00   Yearly            12.00 27,083.33    15.00
# 73234        NaN   Weekly             4.33       NaN    20.00
# 73254 115,000.00   Yearly            12.00  9,583.33    16.00
# 73264 107,000.00   Yearly            12.00  8,916.67     6.00
# 73267        NaN      NaN            12.00       NaN      NaN
#
# [5742 rows x 5 columns]

# %%
dff.isna().sum().head(60)
# Out:
# ResponseId                           0
# MainBranch                           0
# Employment                           0
# RemoteWork                         173
# CodingActivities                   179
# EdLevel                              6
# LearnCode                            4
# LearnCodeOnline                   1574
# LearnCodeCoursesCert              3032
# YearsCode                           34
# YearsCodePro                       992
# DevType                              0
# OrgSize                           1066
# PurchaseInfluence                 1070
# BuyNewTool                         224
# Country                              0
# Currency                          1059
# CompTotal                         2238
# CompFreq                          1682
# LanguageHaveWorkedWith              36
# LanguageWantToWorkWith             365
# DatabaseHaveWorkedWith             763
# DatabaseWantToWorkWith            1515
# PlatformHaveWorkedWith            1463
# ...

# %%
dff.Salary.value_counts().sort_values(ascending=False)
# Out:
# 5,000.00      108
# 10,000.00      93
# 8,333.33       81
# 12,500.00      64
# 4,166.67       55
#              ...
# 548,333.33      1
# 8,675.33        1
# 12,583.33       1
# 2,290.50        1
# 27,083.33       1
# Name: Salary, Length: 779, dtype: int64

# %%
dff.LearnCodeCoursesCert.value_counts()
# Out:
# Udemy                                        306
# Coursera;Udemy                               237
# Coursera                                     218
# Other                                        197
# Coursera;Udemy;edX                            91
#                                             ...
# Codecademy;Udacity;Other                       1
# Coursera;Pluralsight;Udacity;Other             1
# Coursera;Udemy;Udacity;Skillsoft               1
# Coursera;Pluralsight;edX;Other;Skillsoft       1
# Coursera;Codecademy;Pluralsight;edX;Other      1
# Name: LearnCodeCoursesCert, Length: 142, dtype: int64

# %%
dff.loc[dff.CompFreq == 'Monthly'].describe()
# Out:
#        ResponseId            CompTotal  VCHostingPersonal use  \
# count    1,668.00             1,204.00                   0.00
# mean    36,632.63       839,356,468.05                    NaN
# std     20,439.71    28,819,877,922.17                    NaN
# min         40.00                 0.00                    NaN
# 25%     18,989.75             5,000.00                    NaN
# 50%     36,218.00            20,000.00                    NaN
# 75%     53,860.25            90,000.00                    NaN
# max     73,197.00 1,000,000,000,000.00                    NaN
#
#        VCHostingProfessional use  WorkExp  ConvertedCompYearly  \
# count                       0.00 1,102.00             1,191.00
# mean                         NaN    10.46           143,262.39
# std                          NaN     8.62           373,510.31
# min                          NaN     0.00                24.00
# 25%                          NaN     4.00            20,688.00
# ...

# %%
dff.DatabaseHaveWorkedWith.value_counts()
# Out:
# Microsoft SQL Server                                352
# PostgreSQL                                          278
# MySQL                                               204
# PostgreSQL;SQLite                                   141
# SQLite                                              119
#                                                    ...
# IBM DB2;MySQL;Oracle                                  1
# DynamoDB;Microsoft SQL Server;MongoDB;PostgreSQL      1
# DynamoDB;Elasticsearch;MySQL;Oracle                   1
# Cassandra;Couchbase;CouchDB;MongoDB;MySQL;SQLite      1
# Microsoft SQL Server;Neo4j;Redis                      1
# Name: DatabaseHaveWorkedWith, Length: 1153, dtype: int64

# %%
dff.loc[dff.DatabaseHaveWorkedWith.str.contains('ibm', na=False, case=False)].DatabaseHaveWorkedWith
# Out:
# 749                         Elasticsearch;IBM DB2;Microsoft SQL Server;Redis
# 1139                                                          IBM DB2;Oracle
# 3336       IBM DB2;Microsoft SQL Server;MySQL;Oracle;PostgreSQL;Redis;SQLite
# 3453                                                          IBM DB2;SQLite
# 3689            IBM DB2;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;SQLite
#                                         ...
# 72223                                 IBM DB2;MySQL;Oracle;PostgreSQL;SQLite
# 72604                                                   IBM DB2;MySQL;SQLite
# 72806                     IBM DB2;MariaDB;Microsoft SQL Server;MongoDB;MySQL
# 73026    IBM DB2;MariaDB;Microsoft SQL Server;MySQL;Oracle;PostgreSQL;SQLite
# 73176                  IBM DB2;MariaDB;Microsoft SQL Server;MySQL;PostgreSQL
# Name: DatabaseHaveWorkedWith, Length: 217, dtype: object
